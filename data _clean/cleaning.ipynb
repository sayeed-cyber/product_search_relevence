# %%
import pandas as pd 
import numpy as np

# %%
dat=pd.read_csv('category.csv')
dat.size

# %%
dat.drop_duplicates(keep='first',inplace=True)
dat=dat.values

# %%
lis=[]
for i in dat:
    lis.append(i)

products = [  "Gym clothes",
        "Workout clothes",
        "Yoga pants",
        "Running tights",
        "Sport shorts",
        "Sweatshirt",
        "Track jacket",
        "Sports bra",
        "Swimwear",
        "Cycling shorts",
        "Gym shoes",
        "Sweatband",
        "Running hat", "T-shirt",
        "Shirt",
        "Tank top",
        "Henley",
        "Hoodie",
        "Sweatshirt",
        "Sweater",
        "Jacket",
        "Blouse",
        "Kurta",
        "Tunic",
        "Turtle neck",
        "Polo shirt",
        "Vest","T-shirt",  "Pants",
        "Trousers",
        "Slacks",
        "Jeans",
        "Chinos",
        "Joggers",
        "Sweatpants",
        "Track pants",
        "Leggings",
        "Shorts",
        "Skirt",
        "Sarong",
        "Dhoti",
        "Pajama",
        "Salwar",
        "Lehenga", "Shoes",
        "Sneakers",
        "Sandals",
        "Flip flops",
        "Slippers",
        "Boots",
        "Sport shoes",
        "Running shoes",
        "Hiking shoes",
        "Dress shoes",
        "Loafers",
        "Oxford shoes",
        "Canvas shoes",
        "Clogs", "Watch",
        "Sunglasses",
        "Belt",
        "Bag",
        "Wallet",
        "Backpack",
        "Luggage",
        "Hat",
        "Scarf",
        "Gloves",
        "Socks",
        "Tie",
        "Bowtie",
        "Pocket square",
        "Cufflinks",
        "Jewellery",
        "Umbrella","Gym clothes",
        "Workout clothes",
        "Yoga pants",
        "Running tights",
        "Sport shorts",
        "Sweatshirt",
        "Track jacket",
        "Sports bra",
        "Swimwear",
        "Cycling shorts",
        "Gym shoes",
        "Sweatband",
        "Running hat",    "Shirt",    "Jeans",    "Trousers",    "Shorts",    "Sneakers",    "Shoes",    "Sandals",    "Boots",    "Watch",    "Sunglasses",    "Belt",    "Bag",    "Wallet",    "Backpack",    "Luggage",    "Activewear",    "Sport shoes",    "Gym equipment",    "Yoga mats",    "Shaving products",  "Clothing",    "T-shirt",    "Shirt",    "Jeans",    "Trousers",    "Shorts",    "Skirt",    "Dress",    "Ethnic wear",    "Saree",    "Kurti",    "Lehenga",    "Salwar suit",    "Footwear",    "Shoe",    "Sneaker",    "Sandals",    "Flip flops",    "Slippers",    "Boots",    "Accessories",    "Watch",    "Sunglasses",    "Belt",    "Bag",    "Wallet",    "Backpack",    "Luggage",    "Jewelry",    "Earrings",    "Necklace",    "Bracelet",    "Ring",    "Beauty",    "Makeup",    "Skin care products",    "Hair care products",    "Fragrances",    "Home decor",    "Bed sheets",    "Towels",    "Curtains",    "Cushions",    "Furniture",    "Sofas",    "Chairs",    "Tables",    "Lamps",    "Sports & Fitness",    "Gym equipment",    "Yoga mats",    "Sports shoes",    "Activewear",    "Kidswear",    "Footwear",    "Lifestyle",    "Grooming",    "Shaving products"]
for i in products:
    lis.append(str(i).lower())

# %%
dat=np.array(lis)
dat=pd.Series(dat)

# %%
dat.size

# %%
dat.drop_duplicates(keep='first',inplace=True)

# %%
dat.to_csv('category.csv',index=False)

# %%
fashion_product_names = {
    "Tops": [
        "T-shirt",
        "Shirt",
        "Tank top",
        "Henley",
        "Hoodie",
        "Sweatshirt",
        "Sweater",
        "Jacket",
        "Blouse",
        "Kurta",
        "Tunic",
        "Turtle neck",
        "Polo shirt",
        "Vest"
    ],
    "Bottoms": [
        "Pants",
        "Trousers",
        "Slacks",
        "Jeans",
        "Chinos",
        "Joggers",
        "Sweatpants",
        "Track pants",
        "Leggings",
        "Shorts",
        "Skirt",
        "Sarong",
        "Dhoti",
        "Pajama",
        "Salwar",
        "Lehenga"
    ],
    "Footwear": [
        "Shoes",
        "Sneakers",
        "Sandals",
        "Flip flops",
        "Slippers",
        "Boots",
        "Sport shoes",
        "Running shoes",
        "Hiking shoes",
        "Dress shoes",
        "Loafers",
        "Oxford shoes",
        "Canvas shoes",
        "Clogs"
    ],
    "Accessories": [
        "Watch",
        "Sunglasses",
        "Belt",
        "Bag",
        "Wallet",
        "Backpack",
        "Luggage",
        "Hat",
        "Scarf",
        "Gloves",
        "Socks",
        "Tie",
        "Bowtie",
        "Pocket square",
        "Cufflinks",
        "Jewellery",
        "Umbrella"
    ],
    "Activewear": [
        "Gym clothes",
        "Workout clothes",
        "Yoga pants",
        "Running tights",
        "Sport shorts",
        "Sweatshirt",
        "Track jacket",
        "Sports bra",
        "Swimwear",
        "Cycling shorts",
        "Gym shoes",
        "Sweatband",
        "Running hat"
    ]
}
